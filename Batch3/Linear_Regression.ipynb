# %%
import findspark
findspark.init()
from pyspark import SparkConf, SparkContext
from pyspark.sql import SparkSession
spark=SparkSessio.builder.appName('tree').master('local[3]').getOrCreate()
sqlContext = SQLContext(sc)

# %%
house_df = spark.read.format('csv').options(header='true', inferschema='true').load(r'C:\Users\Krishna\Downloads\9ngq7dgydy\651_m8_codes_v1.0\boston.csv')
house_df.take(1)
# Out:
# [Row(CRIM=0.00632, ZN=18.0, INDUS=2.309999943, CHAS=0, NOX=0.537999988, RM=6.574999809, AGE=65.19999695, DIS=4.090000153, RAD=1, TAX=296, PT=15.30000019, B=396.8999939, LSTAT=4.980000019, MV=24.0)]

# %%
house_df.cache()
house_df.printSchema()
# Out:
# root
#  |-- CRIM: double (nullable = true)
#  |-- ZN: double (nullable = true)
#  |-- INDUS: double (nullable = true)
#  |-- CHAS: integer (nullable = true)
#  |-- NOX: double (nullable = true)
#  |-- RM: double (nullable = true)
#  |-- AGE: double (nullable = true)
#  |-- DIS: double (nullable = true)
#  |-- RAD: integer (nullable = true)
#  |-- TAX: integer (nullable = true)
#  |-- PT: double (nullable = true)
#  |-- B: double (nullable = true)
#  |-- LSTAT: double (nullable = true)
#  |-- MV: double (nullable = true)

# %%
house_df.describe().toPandas().transpose()
# Out:
#              0                   1                   2            3  \
# summary  count                mean              stddev          min
# CRIM       506  3.6135235608162057   8.601545086715594      0.00632
# ZN         506  11.363636363636363   23.32245299451514          0.0
# INDUS      506  11.136778749531626    6.86035298095724  0.460000008
# CHAS       506  0.0691699604743083  0.2539940413404101            0
# NOX        506  0.5546950602312246  0.1158776754570543   0.38499999
# RM         506    6.28463438896641  0.7026171549511354  3.561000109
# AGE        506   68.57490120115612  28.148861532793276  2.900000095
# DIS        506  3.7950426960059325   2.105710142043288  1.129600048
# RAD        506   9.549407114624506   8.707259384239366            1
# TAX        506   408.2371541501976  168.53711605495903          187
# PT         506   18.45553382776679   2.164945780039869  12.60000038
# B          506  356.67402960597883   91.29486340272308  0.319999993
# LSTAT      506  12.653063233922925   7.141061500195388  1.730000019
# MV         506   22.53280636250988   9.197104107945272          5.0
#
#                    4
# summary          max
# CRIM     88.97619629
# ZN             100.0
# INDUS    27.73999977
# CHAS               1
# NOX      0.870999992
# RM       8.779999733
# AGE            100.0
# DIS      12.12650013
# RAD               24
# TAX              711
# PT              22.0
# B        396.8999939
# LSTAT    37.97000122
# MV              50.0

# %%
import pandas as pd

# %%
numeric_features = [t[0] for t in house_df.dtypes if t[1] == 'int' or t[1] == 'double']
sampled_data = house_df.select(numeric_features).sample(False, 0.8).toPandas()
axs = pd.plotting.scatter_matrix(sampled_data, figsize=(10, 10))
n = len(sampled_data.columns)
for i in range(n):
    v = axs[i, 0]
    v.yaxis.label.set_rotation(0)
    v.yaxis.label.set_ha('right')
    v.set_yticks(())
    h = axs[n-1, i]
    h.xaxis.label.set_rotation(90)
    h.set_xticks(())

# %%
import six
for i in house_df.columns:
    if not( isinstance(house_df.select(i).take(1)[0][0], six.string_types)):
        print( "Correlation to MV for ", i, house_df.stat.corr('MV',i))
# Out:
# ('Correlation to MV for ', 'CRIM', -0.3883046116575088)
# ('Correlation to MV for ', 'ZN', 0.36044534463752903)
# ('Correlation to MV for ', 'INDUS', -0.48372517128143383)
# ('Correlation to MV for ', 'CHAS', 0.17526017775291847)
# ('Correlation to MV for ', 'NOX', -0.4273207763683772)
# ('Correlation to MV for ', 'RM', 0.695359937127267)
# ('Correlation to MV for ', 'AGE', -0.37695456714288667)
# ('Correlation to MV for ', 'DIS', 0.24992873873512172)
# ('Correlation to MV for ', 'RAD', -0.3816262315669168)
# ('Correlation to MV for ', 'TAX', -0.46853593528654536)
# ('Correlation to MV for ', 'PT', -0.5077867038116085)
# ('Correlation to MV for ', 'B', 0.3334608226834164)
# ('Correlation to MV for ', 'LSTAT', -0.7376627294671615)
# ('Correlation to MV for ', 'MV', 1.0)

# %%
from pyspark.ml.feature import VectorAssembler
vectorAssembler = VectorAssembler(inputCols = ['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'PT', 'B', 'LSTAT'], outputCol = 'features')
vhouse_df = vectorAssembler.transform(house_df)
vhouse_df = vhouse_df.select(['features', 'MV'])
vhouse_df.show(3)
# Out:
# +--------------------+-----------+
# |            features|         MV|
# +--------------------+-----------+
# |[0.00632,18.0,2.3...|       24.0|
# |[0.027310001,0.0,...|21.60000038|
# |[0.02729,0.0,7.07...|34.70000076|
# +--------------------+-----------+
# only showing top 3 rows

# %%
splits = vhouse_df.randomSplit([0.7, 0.3])
train_df = splits[0]
test_df = splits[1]

# %%
from pyspark.ml.regression import LinearRegression
lr = LinearRegression(featuresCol = 'features', labelCol='MV', maxIter=10, regParam=0.3, elasticNetParam=0.8)
lr_model = lr.fit(train_df)
print("Coefficients: " + str(lr_model.coefficients))
print("Intercept: " + str(lr_model.intercept))
# Out:
# Coefficients: [-0.046132248073,0.00340046406392,-0.00215448931977,0.545876294323,-8.82667857821,3.93073692123,0.0,-0.635398080445,0.0,0.0,-0.957512626956,0.00676671176105,-0.511620039635]
# Intercept: 26.9551200088

# %%
trainingSummary = lr_model.summary
print("RMSE: %f" % trainingSummary.rootMeanSquaredError)
print("r2: %f" % trainingSummary.r2)
# Out:
# RMSE: 4.935111
# r2: 0.710298

# %%
train_df.describe().show()
# Out:
# +-------+------------------+
# |summary|                MV|
# +-------+------------------+
# |  count|               350|
# |   mean|22.236571472682858|
# | stddev|  9.18211355040752|
# |    min|               5.0|
# |    max|              50.0|
# +-------+------------------+

# %%
lr_predictions = lr_model.transform(test_df)
lr_predictions.select("prediction","MV","features").show(5)
from pyspark.ml.evaluation import RegressionEvaluator
lr_evaluator = RegressionEvaluator(predictionCol="prediction", \
                 labelCol="MV",metricName="r2")
print("R Squared (R2) on test data = %g" % lr_evaluator.evaluate(lr_predictions))
# Out:
# +------------------+-----------+--------------------+
# |        prediction|         MV|            features|
# +------------------+-----------+--------------------+
# |28.235595944914074|       22.0|[0.01096,55.0,2.2...|
# | 29.74766248528248|35.40000153|[0.01311,90.0,1.2...|
# | 16.98544151222643|18.89999962|[0.0136,75.0,4.0,...|
# |31.345538812263875|31.60000038|[0.01432,100.0,1....|
# |30.945902033758532|32.90000153|[0.01778,95.0,1.4...|
# +------------------+-----------+--------------------+
# only showing top 5 rows
#
# R Squared (R2) on test data = 0.710824

# %%
test_result = lr_model.evaluate(test_df)
print("Root Mean Squared Error (RMSE) on test data = %g" % test_result.rootMeanSquaredError)
# Out:
# Root Mean Squared Error (RMSE) on test data = 4.9451

# %%
print("numIterations: %d" % trainingSummary.totalIterations)
print("objectiveHistory: %s" % str(trainingSummary.objectiveHistory))
trainingSummary.residuals.show()
# Out:
# numIterations: 11
# objectiveHistory: [0.5, 0.43221190395292297, 0.2349187112448049, 0.21423734748014606, 0.18602537986458537, 0.1833878187303744, 0.18260190707359195, 0.18165035519720643, 0.18094618528502693, 0.18074496332864678, 0.18068994796918103]
# +-------------------+
# |          residuals|
# +-------------------+
# | -6.996019902115471|
# | 1.2535132805952571|
# | 0.5196807438700262|
# | 11.773810597825786|
# |-1.8902651149141754|
# | -2.964267576130016|
# | 10.294370831032637|
# |  9.152908505317797|
# | 3.7005484005969826|
# | -2.799159287209463|
# |   6.86561874762149|
# |-0.7069490077092588|
# | 5.7949790272069635|
# |-0.4405927658706652|
# |-3.7988193266321524|
# | -4.247867535654805|
# | 1.9394975627843287|
# | -2.083485279408592|
# | 0.8490755640388521|
# |-1.4278318115834878|
# +-------------------+
# only showing top 20 rows

# %%
predictions = lr_model.transform(test_df)
predictions.select("prediction","MV","features").show()
# Out:
# +------------------+-----------+--------------------+
# |        prediction|         MV|            features|
# +------------------+-----------+--------------------+
# |28.235595944914074|       22.0|[0.01096,55.0,2.2...|
# | 29.74766248528248|35.40000153|[0.01311,90.0,1.2...|
# | 16.98544151222643|18.89999962|[0.0136,75.0,4.0,...|
# |31.345538812263875|31.60000038|[0.01432,100.0,1....|
# |30.945902033758532|32.90000153|[0.01778,95.0,1.4...|
# | 39.02009493338487|       50.0|[0.020090001,95.0...|
# | 26.04348132480287|24.70000076|[0.02055,85.0,0.7...|
# | 27.09150242850147|       16.5|[0.024979999,0.0,...|
# | 31.43778951070596|34.70000076|[0.02729,0.0,7.07...|
# | 26.42502391887756|28.70000076|[0.029850001,0.0,...|
# |29.186755696747873|31.20000076|[0.03049,55.0,3.7...|
# |28.591635320450823|24.10000038|[0.034449998,82.5...|
# | 37.84722148197834|       48.5|[0.035100002,95.0...|
# |28.049754752087125|       22.0|[0.03537,34.0,6.0...|
# |25.662598920145662|24.79999924|[0.036589999,25.0...|
# |22.935535830663877|20.70000076|[0.037379999,0.0,...|
# |34.806542591505234|34.59999847|[0.03768,80.0,1.5...|
# | 27.26540105047632|       22.0|[0.03932,0.0,3.41...|
# | 21.56905832201943|21.10000038|[0.039609998,0.0,...|
# | 36.18884841607944|33.29999924|[0.040109999,80.0...|
# +------------------+-----------+--------------------+
# only showing top 20 rows

# %%
pip install jupyterlab==3
# Out:
# Collecting jupyterlab==3
#   Downloading jupyterlab-3.0.0-py3-none-any.whl (8.3 MB)
#      ---------------------------------------- 8.3/8.3 MB 8.5 MB/s eta 0:00:00
# Requirement already satisfied: tornado>=6.1.0 in c:\users\krishna\anaconda3\lib\site-packages (from jupyterlab==3) (6.1)
# Requirement already satisfied: jupyterlab-server~=2.0 in c:\users\krishna\anaconda3\lib\site-packages (from jupyterlab==3) (2.10.3)
# Requirement already satisfied: jupyter-core in c:\users\krishna\anaconda3\lib\site-packages (from jupyterlab==3) (4.11.1)
# Requirement already satisfied: ipython in c:\users\krishna\anaconda3\lib\site-packages (from jupyterlab==3) (7.31.1)
# Requirement already satisfied: packaging in c:\users\krishna\anaconda3\lib\site-packages (from jupyterlab==3) (24.1)
# Requirement already satisfied: jinja2>=2.10 in c:\users\krishna\anaconda3\lib\site-packages (from jupyterlab==3) (2.11.3)
# Requirement already satisfied: jupyter-server~=1.1 in c:\users\krishna\anaconda3\lib\site-packages (from jupyterlab==3) (1.18.1)
# Requirement already satisfied: nbclassic~=0.2 in c:\users\krishna\anaconda3\lib\site-packages (from jupyterlab==3) (0.3.5)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\krishna\anaconda3\lib\site-packages (from jinja2>=2.10->jupyterlab==3) (2.0.1)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\krishna\anaconda3\lib\site-packages (from jupyter-server~=1.1->jupyterlab==3) (7.3.4)
# Requirement already satisfied: Send2Trash in c:\users\krishna\anaconda3\lib\site-packages (from jupyter-server~=1.1->jupyterlab==3) (1.8.0)
# Requirement already satisfied: traitlets>=5.1 in c:\users\krishna\anaconda3\lib\site-packages (from jupyter-server~=1.1->jupyterlab==3) (5.1.1)
# Requirement already satisfied: nbconvert>=6.4.4 in c:\users\krishna\anaconda3\lib\site-packages (from jupyter-server~=1.1->jupyterlab==3) (6.4.4)
# Requirement already satisfied: nbformat>=5.2.0 in c:\users\krishna\anaconda3\lib\site-packages (from jupyter-server~=1.1->jupyterlab==3) (5.5.0)
# Requirement already satisfied: prometheus-client in c:\users\krishna\anaconda3\lib\site-packages (from jupyter-server~=1.1->jupyterlab==3) (0.14.1)
# Requirement already satisfied: pyzmq>=17 in c:\users\krishna\anaconda3\lib\site-packages (from jupyter-server~=1.1->jupyterlab==3) (23.2.0)
# Requirement already satisfied: websocket-client in c:\users\krishna\anaconda3\lib\site-packages (from jupyter-server~=1.1->jupyterlab==3) (0.58.0)
# Requirement already satisfied: argon2-cffi in c:\users\krishna\anaconda3\lib\site-packages (from jupyter-server~=1.1->jupyterlab==3) (21.3.0)
# Requirement already satisfied: anyio<4,>=3.1.0 in c:\users\krishna\anaconda3\lib\site-packages (from jupyter-server~=1.1->jupyterlab==3) (3.5.0)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\krishna\anaconda3\lib\site-packages (from jupyter-server~=1.1->jupyterlab==3) (0.13.1)
# Requirement already satisfied: pywinpty in c:\users\krishna\anaconda3\lib\site-packages (from jupyter-server~=1.1->jupyterlab==3) (2.0.2)
# Requirement already satisfied: pywin32>=1.0 in c:\users\krishna\anaconda3\lib\site-packages (from jupyter-core->jupyterlab==3) (302)
# Requirement already satisfied: babel in c:\users\krishna\anaconda3\lib\site-packages (from jupyterlab-server~=2.0->jupyterlab==3) (2.9.1)
# Requirement already satisfied: jsonschema>=3.0.1 in c:\users\krishna\anaconda3\lib\site-packages (from jupyterlab-server~=2.0->jupyterlab==3) (4.16.0)
# Requirement already satisfied: entrypoints>=0.2.2 in c:\users\krishna\anaconda3\lib\site-packages (from jupyterlab-server~=2.0->jupyterlab==3) (0.4)
# Requirement already satisfied: json5 in c:\users\krishna\anaconda3\lib\site-packages (from jupyterlab-server~=2.0->jupyterlab==3) (0.9.6)
# Requirement already satisfied: requests in c:\users\krishna\anaconda3\lib\site-packages (from jupyterlab-server~=2.0->jupyterlab==3) (2.28.1)
# Requirement already satisfied: notebook<7 in c:\users\krishna\anaconda3\lib\site-packages (from nbclassic~=0.2->jupyterlab==3) (6.4.12)
# Requirement already satisfied: jedi>=0.16 in c:\users\krishna\anaconda3\lib\site-packages (from ipython->jupyterlab==3) (0.18.1)
# Requirement already satisfied: pickleshare in c:\users\krishna\anaconda3\lib\site-packages (from ipython->jupyterlab==3) (0.7.5)
# Requirement already satisfied: decorator in c:\users\krishna\anaconda3\lib\site-packages (from ipython->jupyterlab==3) (5.1.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\krishna\anaconda3\lib\site-packages (from ipython->jupyterlab==3) (3.0.20)
# Requirement already satisfied: colorama in c:\users\krishna\anaconda3\lib\site-packages (from ipython->jupyterlab==3) (0.4.5)
# Requirement already satisfied: backcall in c:\users\krishna\anaconda3\lib\site-packages (from ipython->jupyterlab==3) (0.2.0)
# Requirement already satisfied: matplotlib-inline in c:\users\krishna\anaconda3\lib\site-packages (from ipython->jupyterlab==3) (0.1.6)
# Requirement already satisfied: pygments in c:\users\krishna\anaconda3\lib\site-packages (from ipython->jupyterlab==3) (2.18.0)
# Requirement already satisfied: setuptools>=18.5 in c:\users\krishna\anaconda3\lib\site-packages (from ipython->jupyterlab==3) (63.4.1)
# Requirement already satisfied: idna>=2.8 in c:\users\krishna\anaconda3\lib\site-packages (from anyio<4,>=3.1.0->jupyter-server~=1.1->jupyterlab==3) (3.3)
# Requirement already satisfied: sniffio>=1.1 in c:\users\krishna\anaconda3\lib\site-packages (from anyio<4,>=3.1.0->jupyter-server~=1.1->jupyterlab==3) (1.2.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\krishna\anaconda3\lib\site-packages (from jedi>=0.16->ipython->jupyterlab==3) (0.8.3)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\krishna\anaconda3\lib\site-packages (from jsonschema>=3.0.1->jupyterlab-server~=2.0->jupyterlab==3) (21.4.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\krishna\anaconda3\lib\site-packages (from jsonschema>=3.0.1->jupyterlab-server~=2.0->jupyterlab==3) (0.18.0)
# Requirement already satisfied: nest-asyncio>=1.5.4 in c:\users\krishna\anaconda3\lib\site-packages (from jupyter-client>=6.1.12->jupyter-server~=1.1->jupyterlab==3) (1.5.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\krishna\anaconda3\lib\site-packages (from jupyter-client>=6.1.12->jupyter-server~=1.1->jupyterlab==3) (2.8.2)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\krishna\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server~=1.1->jupyterlab==3) (0.8.4)
# Requirement already satisfied: jupyterlab-pygments in c:\users\krishna\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server~=1.1->jupyterlab==3) (0.1.2)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in c:\users\krishna\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server~=1.1->jupyterlab==3) (0.5.13)
# Requirement already satisfied: defusedxml in c:\users\krishna\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server~=1.1->jupyterlab==3) (0.7.1)
# Requirement already satisfied: beautifulsoup4 in c:\users\krishna\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server~=1.1->jupyterlab==3) (4.11.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\krishna\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server~=1.1->jupyterlab==3) (1.5.0)
# Requirement already satisfied: bleach in c:\users\krishna\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server~=1.1->jupyterlab==3) (4.1.0)
# Requirement already satisfied: testpath in c:\users\krishna\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server~=1.1->jupyterlab==3) (0.6.0)
# Requirement already satisfied: fastjsonschema in c:\users\krishna\anaconda3\lib\site-packages (from nbformat>=5.2.0->jupyter-server~=1.1->jupyterlab==3) (2.16.2)
# Requirement already satisfied: ipython-genutils in c:\users\krishna\anaconda3\lib\site-packages (from notebook<7->nbclassic~=0.2->jupyterlab==3) (0.2.0)
# Requirement already satisfied: ipykernel in c:\users\krishna\anaconda3\lib\site-packages (from notebook<7->nbclassic~=0.2->jupyterlab==3) (6.15.2)
# Requirement already satisfied: wcwidth in c:\users\krishna\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->jupyterlab==3) (0.2.5)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\krishna\anaconda3\lib\site-packages (from argon2-cffi->jupyter-server~=1.1->jupyterlab==3) (21.2.0)
# Requirement already satisfied: pytz>=2015.7 in c:\users\krishna\anaconda3\lib\site-packages (from babel->jupyterlab-server~=2.0->jupyterlab==3) (2022.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\krishna\anaconda3\lib\site-packages (from requests->jupyterlab-server~=2.0->jupyterlab==3) (1.26.11)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\krishna\anaconda3\lib\site-packages (from requests->jupyterlab-server~=2.0->jupyterlab==3) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\krishna\anaconda3\lib\site-packages (from requests->jupyterlab-server~=2.0->jupyterlab==3) (2022.9.14)
# Requirement already satisfied: six in c:\users\krishna\anaconda3\lib\site-packages (from websocket-client->jupyter-server~=1.1->jupyterlab==3) (1.16.0)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\krishna\anaconda3\lib\site-packages (from argon2-cffi-bindings->argon2-cffi->jupyter-server~=1.1->jupyterlab==3) (1.15.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\krishna\anaconda3\lib\site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server~=1.1->jupyterlab==3) (2.3.1)
# Requirement already satisfied: webencodings in c:\users\krishna\anaconda3\lib\site-packages (from bleach->nbconvert>=6.4.4->jupyter-server~=1.1->jupyterlab==3) (0.5.1)
# Requirement already satisfied: psutil in c:\users\krishna\anaconda3\lib\site-packages (from ipykernel->notebook<7->nbclassic~=0.2->jupyterlab==3) (5.9.0)
# Requirement already satisfied: debugpy>=1.0 in c:\users\krishna\anaconda3\lib\site-packages (from ipykernel->notebook<7->nbclassic~=0.2->jupyterlab==3) (1.5.1)
# Requirement already satisfied: pycparser in c:\users\krishna\anaconda3\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->jupyter-server~=1.1->jupyterlab==3) (2.21)
# Installing collected packages: jupyterlab
#   Attempting uninstall: jupyterlab
#     Found existing installation: jupyterlab 3.4.4
#     Uninstalling jupyterlab-3.4.4:
#       Successfully uninstalled jupyterlab-3.4.4
# Successfully installed jupyterlab-3.0.0
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install xeus-python notebook
# Out:
# Collecting xeus-python
#   Downloading xeus_python-0.15.12-cp39-cp39-win_amd64.whl (1.5 MB)
#      ---------------------------------------- 1.5/1.5 MB 4.7 MB/s eta 0:00:00
# Requirement already satisfied: notebook in c:\users\krishna\anaconda3\lib\site-packages (6.4.12)
# Collecting xeus-python-shell[ipython]<0.6,>=0.5
#   Downloading xeus_python_shell-0.5.0-py3-none-any.whl (8.1 kB)
# Requirement already satisfied: pygments<3,>=2.3.1 in c:\users\krishna\anaconda3\lib\site-packages (from xeus-python) (2.18.0)
# Requirement already satisfied: ipython-genutils in c:\users\krishna\anaconda3\lib\site-packages (from notebook) (0.2.0)
# Requirement already satisfied: argon2-cffi in c:\users\krishna\anaconda3\lib\site-packages (from notebook) (21.3.0)
# Requirement already satisfied: nbformat in c:\users\krishna\anaconda3\lib\site-packages (from notebook) (5.5.0)
# Requirement already satisfied: jupyter-core>=4.6.1 in c:\users\krishna\anaconda3\lib\site-packages (from notebook) (4.11.1)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\krishna\anaconda3\lib\site-packages (from notebook) (0.13.1)
# Requirement already satisfied: nbconvert>=5 in c:\users\krishna\anaconda3\lib\site-packages (from notebook) (6.4.4)
# Requirement already satisfied: traitlets>=4.2.1 in c:\users\krishna\anaconda3\lib\site-packages (from notebook) (5.1.1)
# Requirement already satisfied: Send2Trash>=1.8.0 in c:\users\krishna\anaconda3\lib\site-packages (from notebook) (1.8.0)
# Requirement already satisfied: ipykernel in c:\users\krishna\anaconda3\lib\site-packages (from notebook) (6.15.2)
# Requirement already satisfied: jinja2 in c:\users\krishna\anaconda3\lib\site-packages (from notebook) (2.11.3)
# Requirement already satisfied: prometheus-client in c:\users\krishna\anaconda3\lib\site-packages (from notebook) (0.14.1)
# Requirement already satisfied: pyzmq>=17 in c:\users\krishna\anaconda3\lib\site-packages (from notebook) (23.2.0)
# Requirement already satisfied: nest-asyncio>=1.5 in c:\users\krishna\anaconda3\lib\site-packages (from notebook) (1.5.5)
# Requirement already satisfied: jupyter-client>=5.3.4 in c:\users\krishna\anaconda3\lib\site-packages (from notebook) (7.3.4)
# Requirement already satisfied: tornado>=6.1 in c:\users\krishna\anaconda3\lib\site-packages (from notebook) (6.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\krishna\anaconda3\lib\site-packages (from jupyter-client>=5.3.4->notebook) (2.8.2)
# Requirement already satisfied: entrypoints in c:\users\krishna\anaconda3\lib\site-packages (from jupyter-client>=5.3.4->notebook) (0.4)
# Requirement already satisfied: pywin32>=1.0 in c:\users\krishna\anaconda3\lib\site-packages (from jupyter-core>=4.6.1->notebook) (302)
# Requirement already satisfied: beautifulsoup4 in c:\users\krishna\anaconda3\lib\site-packages (from nbconvert>=5->notebook) (4.11.1)
# Requirement already satisfied: testpath in c:\users\krishna\anaconda3\lib\site-packages (from nbconvert>=5->notebook) (0.6.0)
# Requirement already satisfied: jupyterlab-pygments in c:\users\krishna\anaconda3\lib\site-packages (from nbconvert>=5->notebook) (0.1.2)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\krishna\anaconda3\lib\site-packages (from nbconvert>=5->notebook) (0.8.4)
# Requirement already satisfied: defusedxml in c:\users\krishna\anaconda3\lib\site-packages (from nbconvert>=5->notebook) (0.7.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\krishna\anaconda3\lib\site-packages (from nbconvert>=5->notebook) (1.5.0)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in c:\users\krishna\anaconda3\lib\site-packages (from nbconvert>=5->notebook) (0.5.13)
# Requirement already satisfied: bleach in c:\users\krishna\anaconda3\lib\site-packages (from nbconvert>=5->notebook) (4.1.0)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\krishna\anaconda3\lib\site-packages (from jinja2->notebook) (2.0.1)
# Requirement already satisfied: fastjsonschema in c:\users\krishna\anaconda3\lib\site-packages (from nbformat->notebook) (2.16.2)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\krishna\anaconda3\lib\site-packages (from nbformat->notebook) (4.16.0)
# Requirement already satisfied: pywinpty>=1.1.0 in c:\users\krishna\anaconda3\lib\site-packages (from terminado>=0.8.3->notebook) (2.0.2)
# Requirement already satisfied: debugpy<2,>=1.1.0 in c:\users\krishna\anaconda3\lib\site-packages (from xeus-python-shell[ipython]<0.6,>=0.5->xeus-python) (1.5.1)
# Requirement already satisfied: ipython<9,>=7.21 in c:\users\krishna\anaconda3\lib\site-packages (from xeus-python-shell[ipython]<0.6,>=0.5->xeus-python) (7.31.1)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\krishna\anaconda3\lib\site-packages (from argon2-cffi->notebook) (21.2.0)
# Requirement already satisfied: psutil in c:\users\krishna\anaconda3\lib\site-packages (from ipykernel->notebook) (5.9.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\krishna\anaconda3\lib\site-packages (from ipykernel->notebook) (0.1.6)
# Requirement already satisfied: packaging in c:\users\krishna\anaconda3\lib\site-packages (from ipykernel->notebook) (24.1)
# Requirement already satisfied: colorama in c:\users\krishna\anaconda3\lib\site-packages (from ipython<9,>=7.21->xeus-python-shell[ipython]<0.6,>=0.5->xeus-python) (0.4.5)
# Requirement already satisfied: backcall in c:\users\krishna\anaconda3\lib\site-packages (from ipython<9,>=7.21->xeus-python-shell[ipython]<0.6,>=0.5->xeus-python) (0.2.0)
# Requirement already satisfied: decorator in c:\users\krishna\anaconda3\lib\site-packages (from ipython<9,>=7.21->xeus-python-shell[ipython]<0.6,>=0.5->xeus-python) (5.1.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\krishna\anaconda3\lib\site-packages (from ipython<9,>=7.21->xeus-python-shell[ipython]<0.6,>=0.5->xeus-python) (3.0.20)
# Requirement already satisfied: jedi>=0.16 in c:\users\krishna\anaconda3\lib\site-packages (from ipython<9,>=7.21->xeus-python-shell[ipython]<0.6,>=0.5->xeus-python) (0.18.1)
# Requirement already satisfied: pickleshare in c:\users\krishna\anaconda3\lib\site-packages (from ipython<9,>=7.21->xeus-python-shell[ipython]<0.6,>=0.5->xeus-python) (0.7.5)
# Requirement already satisfied: setuptools>=18.5 in c:\users\krishna\anaconda3\lib\site-packages (from ipython<9,>=7.21->xeus-python-shell[ipython]<0.6,>=0.5->xeus-python) (63.4.1)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\krishna\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat->notebook) (21.4.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\krishna\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat->notebook) (0.18.0)
# Requirement already satisfied: six>=1.5 in c:\users\krishna\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->jupyter-client>=5.3.4->notebook) (1.16.0)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\krishna\anaconda3\lib\site-packages (from argon2-cffi-bindings->argon2-cffi->notebook) (1.15.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\krishna\anaconda3\lib\site-packages (from beautifulsoup4->nbconvert>=5->notebook) (2.3.1)
# Requirement already satisfied: webencodings in c:\users\krishna\anaconda3\lib\site-packages (from bleach->nbconvert>=5->notebook) (0.5.1)
# Requirement already satisfied: pycparser in c:\users\krishna\anaconda3\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook) (2.21)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\krishna\anaconda3\lib\site-packages (from jedi>=0.16->ipython<9,>=7.21->xeus-python-shell[ipython]<0.6,>=0.5->xeus-python) (0.8.3)
# Requirement already satisfied: wcwidth in c:\users\krishna\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython<9,>=7.21->xeus-python-shell[ipython]<0.6,>=0.5->xeus-python) (0.2.5)
# Installing collected packages: xeus-python-shell, xeus-python
# Successfully installed xeus-python-0.15.12 xeus-python-shell-0.5.0
# Note: you may need to restart the kernel to use updated packages.
